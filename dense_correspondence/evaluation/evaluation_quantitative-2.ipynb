# %% [markdown]
# ## Runs quantitative evaluation for a given network
# Computes 3 things
#
# - descriptor_statistics.yaml
# - Pandas dataframes for info on both test, train, and cross-scene data splits

# %%
# %load_ext autoreload 
# %autoreload 2
# %matplotlib inline

import dense_correspondence_manipulation.utils.utils as utils
import os

utils.add_dense_correspondence_to_python_path()
utils.set_cuda_visible_devices([0])

from dense_correspondence.evaluation.evaluation import DenseCorrespondenceEvaluation
from dense_correspondence.dataset.spartan_dataset_masked import SpartanDataset
import logging
logging.basicConfig(level=logging.INFO)

import pandas as pd
import numpy as np
import time
# Out:
# setting CUDA_VISIBLE_DEVICES =  0,

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %%
model_folder = logging_dir = "tomasz/data/pdc/trained_models/shoes_aploss_3d_don_150_1:2_seed_5"
DCE = DenseCorrespondenceEvaluation
start_time = time.time()
DCE.run_evaluation_on_network(model_folder, num_image_pairs=100, cross_scene=True, compute_descriptor_statistics=True)
print "elapsed time = %d seconds" % (time.time() - start_time)
# Out:
# INFO:root:Computing descriptor statistics on dataset
# INFO:root:Loading pose data for scene 2018-05-15-00-08-46
# INFO:root:Loading pose data for scene 2018-05-15-00-28-06
# Using SpartanDataset:
#    - in train mode
#    - number of scenes 16
#    - total images:     5849
# INFO:root:Loading pose data for scene 2018-05-15-00-26-19
# INFO:root:Loading pose data for scene 2018-05-15-00-29-54
# INFO:root:Loading pose data for scene 2018-05-14-22-15-08
# INFO:root:Loading pose data for scene 2018-05-14-23-02-05
# INFO:root:Loading pose data for scene 2018-05-14-23-37-43
# INFO:root:Loading pose data for scene 2018-05-14-23-44-17
# INFO:root:Loading pose data for scene 2018-05-15-00-04-06
# INFO:root:Loading pose data for scene 2018-05-14-22-10-53
# INFO:root:Loading pose data for scene 2018-05-14-22-19-06
# INFO:root:Loading pose data for scene 2018-05-14-23-00-04
# INFO:root:Loading pose data for scene 2018-05-15-00-06-46
# INFO:root:Loading pose data for scene 2018-05-14-23-46-34
# ...

# %%
# model_folder = os.path.join(logging_dir, name)
# model_folder = utils.convert_data_relative_path_to_absolute_path(model_folder)

# DCE = DenseCorrespondenceEvaluation
# num_image_pairs = 100
# DCE.run_evaluation_on_network(model_folder, num_image_pairs=num_image_pairs)
